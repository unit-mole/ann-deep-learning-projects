# %% [markdown]
# # Multi-Output Prediction System — Leakage-Safe Portfolio Notebook
#
# This notebook uses the modular project code. It predicts churn, CLV, and engagement with one shared ANN and three output heads.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT))
from src.data_generation import generate_synthetic_customer_data
from src.model_training import train

# %% [markdown]
# ## Generate the synthetic dataset

# %%
df = generate_synthetic_customer_data()
df.shape, df[["churn", "clv", "engagement_score"]].describe()

# %% [markdown]
# ## Train and evaluate
#
# The training module performs train/validation/test splitting, train-only feature bin fitting, preprocessing, multi-head ANN training, validation threshold selection, held-out evaluation, and artifact saving.

# %%
metrics = train(PROJECT_ROOT, epochs=40)
metrics

# %% [markdown]
# ## Deployment
#
# Run `streamlit run streamlit_app.py` from the project root. The app loads the saved Keras model, preprocessor, target metadata, and validation-selected threshold.
